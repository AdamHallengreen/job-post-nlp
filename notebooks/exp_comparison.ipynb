# %%
from exp_comparisons import print_all_experiments_text, print_experiment_yaml

# %%
print_experiment_yaml("2f76290")
# Out:
# ...
# EXPERIMENT: kaput-stir  (2f76290c02bd)
# --------------------------------------------------------------------------------
# 0:
# - landsoverenskomst
# - medarbejder borger
# - finde
# - deltid
# - profil logge
# - relevant introduktion
# - ret empati
# - duos
# - slå samarbejde
# - rådgiver sparring
# 1:
# - trykke ansøg
# - ansøgning søge
# - trykke
# - kvalifikation opstart
# - personlig præference
# - læse inden
# - præference søge
# - privatlivspolitik læse
# - ringe mhp
# - samtale dernæst
# 2:
# - kvalifikatione
# - arbejdsopgaver
# - personlige kvalifikation
# - personlige
# - faglig kvalifikatione
# - samtale vente
# - frem høre
# - mail mærke
# - se frem
# - kvalifikatione forvente
# 3:
# - barn
# - pædagog
# - pædagogisk
# - voksen
# - forælder
# - trivsel
# - læring
# - anerkendende
# - skole
# - tilgang
# 4:
# - ambition by
# - arbejde bæredygtig
# - jylland stor
# - aarhus kommune
# - aarhus by
# - blomster ambition
# - arbejdsplads professionel
# - virksomhed natur
# ...

# %%
print_all_experiments_text()
# Out:
# ...
# [1/85] EXPERIMENT: kaput-stir  (2f76290c02bd)
# --------------------------------------------------------------------------------
# 0:
# - landsoverenskomst
# - medarbejder borger
# - finde
# - deltid
# - profil logge
# - relevant introduktion
# - ret empati
# - duos
# - slå samarbejde
# - rådgiver sparring
# 1:
# - trykke ansøg
# - ansøgning søge
# - trykke
# - kvalifikation opstart
# - personlig præference
# - læse inden
# - præference søge
# - privatlivspolitik læse
# - ringe mhp
# - samtale dernæst
# 2:
# - kvalifikatione
# - arbejdsopgaver
# - personlige kvalifikation
# - personlige
# - faglig kvalifikatione
# - samtale vente
# - frem høre
# - mail mærke
# - se frem
# - kvalifikatione forvente
# 3:
# - barn
# - pædagog
# - pædagogisk
# - voksen
# - forælder
# - trivsel
# - læring
# - anerkendende
# - skole
# - tilgang
# 4:
# - ambition by
# - arbejde bæredygtig
# - jylland stor
# - aarhus kommune
# - aarhus by
# - blomster ambition
# - arbejdsplads professionel
# ...

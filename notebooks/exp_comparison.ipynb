# %%
from job_post_nlp.utils.interactive import try_inter

try_inter()
from exp_comparisons import print_all_experiments_text, print_experiment_yaml,print_experiments
# Out:
# /home/b281467@PROD.SITAD.DK/.conda/envs/jobpostnlp/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
print_experiment_yaml("9d5e455")
# Out:
# ...
# EXPERIMENT: fixed-dean  (9d5e4552206e)
# --------------------------------------------------------------------------------
# 0:
# - 'landsoverenskomst                        (m:0.076401, s: +1.0)'
# - 'medarbejder borger                       (m:0.075371, s: +1.0)'
# - 'finde                                    (m:0.074584, s: +1.0)'
# - 'deltid                                   (m:0.073982, s: +1.0)'
# - 'profil logge                             (m:0.071618, s: +1.0)'
# - 'relevant introduktion                    (m:0.071618, s: +1.0)'
# - 'ret empati                               (m:0.071618, s: +1.0)'
# - 'duos                                     (m:0.071618, s: +1.0)'
# - 'slå samarbejde                           (m:0.071618, s: +1.0)'
# - 'rådgiver sparring                        (m:0.071618, s: +1.0)'
# 1:
# - 'trykke ansøg                             (m:0.130884, s: +1.0)'
# - 'ansøgning søge                           (m:0.092386, s: +1.0)'
# ...

# %%
print_experiments(["9d5e455","f275907"])
# Out:
# ...
# EXPERIMENT: fixed-dean  (9d5e4552206e)
# --------------------------------------------------------------------------------
# 0:
# - 'landsoverenskomst                        (m:0.076401, s: +1.0)'
# - 'medarbejder borger                       (m:0.075371, s: +1.0)'
# - 'finde                                    (m:0.074584, s: +1.0)'
# - 'deltid                                   (m:0.073982, s: +1.0)'
# - 'profil logge                             (m:0.071618, s: +1.0)'
# - 'relevant introduktion                    (m:0.071618, s: +1.0)'
# - 'ret empati                               (m:0.071618, s: +1.0)'
# - 'duos                                     (m:0.071618, s: +1.0)'
# - 'slå samarbejde                           (m:0.071618, s: +1.0)'
# - 'rådgiver sparring                        (m:0.071618, s: +1.0)'
# 1:
# - 'trykke ansøg                             (m:0.130884, s: +1.0)'
# - 'ansøgning søge                           (m:0.092386, s: +1.0)'
# ...

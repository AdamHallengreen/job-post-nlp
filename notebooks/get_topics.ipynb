# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import yaml
from corextopic import corextopic as ct
from dvclive import Live
from matplotlib.figure import Figure
from spacy.tokens import DocBin

from job_post_nlp.utils.interactive import try_inter

try_inter()
from job_post_nlp.prepare import corpus_unpack, register_extensions, load_data # noqa: E402
from job_post_nlp.utils.find_project_root import find_project_root  # noqa: E402
from job_post_nlp.evaluate import load_model  # noqa: E402
# Out:
# /home/b281467@PROD.SITAD.DK/.conda/envs/jobpostnlp/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
project_root = Path('..')
project_root.resolve()
# Out:
# PosixPath('/home/b281467@PROD.SITAD.DK/code/job-post-nlp')

# %%
models_dir = project_root / "models"
output_dir = project_root / "output"
metrics = project_root / "metrics.yaml"
top_words_picture = output_dir / "top_words.png"

# Process
model = load_model(models_dir / "corex_model.pkl")

# %%
model.get_topics(topic=0, n_words=10)
# Out:
# [('fleksibel', np.float64(6.846885458899897), np.float64(1.0)),
#  ('flextid', np.float64(0.06581618768938288), np.float64(1.0)),
#  ('hjemmearbejde', np.float64(0.05020491227712003), np.float64(1.0)),
#  ('familievenlig', np.float64(0.04789677869317719), np.float64(1.0)),
#  ('fleksibel forhold', np.float64(0.028173769130615946), np.float64(1.0)),
#  ('mødestabil fleksibel', np.float64(0.021234991093442766), np.float64(1.0)),
#  ('omstillingsparat', np.float64(0.01274739157644171), np.float64(1.0)),
#  ('stabil', np.float64(0.01259916571113709), np.float64(1.0)),
#  ('arbejdstide', np.float64(0.011929337945706137), np.float64(1.0)),
#  ('loyal', np.float64(0.004073460395798589), np.float64(1.0))]

# %%
model.get_topics(topic=30, n_words=10)
# Out:
# [('uanset', np.float64(0.2404706705464839), np.float64(1.0)),
#  ('opfordre', np.float64(0.2387955679742172), np.float64(1.0)),
#  ('etnisk', np.float64(0.18640653340104182), np.float64(1.0)),
#  ('køn', np.float64(0.17852844448351343), np.float64(1.0)),
#  ('religion', np.float64(0.13939701170000252), np.float64(1.0)),
#  ('uanset alder', np.float64(0.10721365414570483), np.float64(1.0)),
#  ('alder', np.float64(0.10578375161741646), np.float64(1.0)),
#  ('alder køn', np.float64(0.10444434577520989), np.float64(1.0)),
#  ('religion etnisk', np.float64(0.10388693725465248), np.float64(1.0)),
#  ('søge stilling', np.float64(0.09746326971704847), np.float64(1.0))]

# %%
# Print all topics from the CorEx topic model
topics = model.get_topics()
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f'{n}: ' + ', '.join(topic_words))
# Out:
# 0: fleksibel, flextid, hjemmearbejde, familievenlig, fleksibel forhold, mødestabil fleksibel, omstillingsparat, stabil, arbejdstide, loyal
# 1: fleksibel, fleksibilitet, ansvarsbevidst, løntakst, tidspunkte, spidsbelastet, arbejdsbelastninge, sikkerhedsorientere, bærentsen, marselis
# 2: fleksibel, fleksibilitet, varsel, respondent, spidsbelastninge, prebens, hovedregle, besværlighede, behandlingsdag, ydertidspunkte
# 3: arbejdstid, fuldtid, deltid, arbejdstid time, ugentlig arbejdstid, røgfri, tilkendt, klapjob, klapjobs, førtidspension
# 4: dagvagt, skift, sundhedsassistent, borger, sygeplejerske, beboer, pårørende, pleje, sygeplejersk, sygepleje
# 5: overenskomst, løn, gælde overenskomst, gælde, ansættelsesvilkår, henhold, henhold gælde, løn ansættelsesvilkår, ansættelsesvilkår henhold, ansættelsesforhold
# 6: vikariat, fastansættelse, tidsbegrænset, projektansættelse, mulighed fastansættelse, mulighed forlængelse, forlængelse, scanpeople, længerevare, scanavo
# ...
